# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Selecting previously unselected package google-drive-ocamlfuse.
# (Reading database ... 145483 files and directories currently installed.)
# Preparing to unpack .../google-drive-ocamlfuse_0.7.23-0ubuntu1~ubuntu18.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.23-0ubuntu1~ubuntu18.04.1) ...
# Setting up google-drive-ocamlfuse (0.7.23-0ubuntu1~ubuntu18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# Please enter the verification code: Access token retrieved correctly.

# %%
#Mount the google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Data Pre-Processing
# ---

# %%
#import necessary libraries
import os

#set directory path for dataset
os.chdir("/content/drive/My Drive/MaskProject")
Dataset='Dataset'
Data_Dir=os.listdir(Dataset)
print(Data_Dir)
# Out:
# ['with_mask', 'without_mask']

# %%
import cv2
import numpy as np
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split

img_rows, img_cols = 112, 112

images = []
labels = []

for category in Data_Dir:
    folder_path = os.path.join(Dataset, category)
    for img in os.listdir(folder_path):
        img_path = os.path.join(folder_path, img)
        img=cv2.imread(img_path)

        try:
            #Coverting the image into gray scale
            grayscale_img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

            #resizing the gray scaled image into size 56x56 in order to keep size of the images consistent           
            resized_img=cv2.resize(grayscale_img,(img_rows, img_cols))
            images.append(resized_img)
            labels.append(category)
        # Exception Handling in case any error occurs
        except Exception as e:
            print('Exception:',e)
        
images=np.array(images)/255.0
images=np.reshape(images,(images.shape[0],img_rows, img_cols,1))

# Perform one hot encoding on the labels since the label are in textual form
lb = LabelBinarizer()
labels = lb.fit_transform(labels)
labels = to_categorical(labels)
labels = np.array(labels)

(train_X, test_X, train_y, test_y) = train_test_split(images, labels, test_size=0.25, 
                                                      random_state=0)

# %% [markdown]
# Build Covolutional Neural Network (CNN) Classification Model

# %%
# Import Necessary Keras Libraries
from keras.models import Sequential
from keras.layers import Dense,Activation,Flatten,Dropout
from keras.layers import Conv2D,MaxPooling2D

# Define model paramters
num_classes = 2
batch_size = 32

# Build CNN model using Sequential API
model=Sequential()

#First layer group containing Convolution, Relu and MaxPooling layers
model.add(Conv2D(64,(3,3),input_shape=(img_rows, img_cols, 1)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

#Second layer group containing Convolution, Relu and MaxPooling layers
model.add(Conv2D(128,(3,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

#Flatten and Dropout Layer to stack the output convolutions above as well as cater overfitting
model.add(Flatten())
model.add(Dropout(0.5))

# Softmax Classifier
model.add(Dense(64,activation='relu'))
model.add(Dense(num_classes,activation='softmax'))

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 110, 110, 64)      640
# _________________________________________________________________
# activation (Activation)      (None, 110, 110, 64)      0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 55, 55, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 53, 53, 128)       73856
# _________________________________________________________________
# activation_1 (Activation)    (None, 53, 53, 128)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 26, 26, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 86528)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 86528)             0
# _________________________________________________________________
# dense (Dense)                (None, 64)                5537856
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 5,612,482
# Trainable params: 5,612,482
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#plot the model
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='face_mask_project2.png')

# %% [markdown]
# Train the Model

# %%
from keras.optimizers import Adam

epochs = 50

model.compile(loss = 'categorical_crossentropy',
              optimizer = Adam(lr=0.001),
              metrics = ['accuracy'])

fitted_model = model.fit(
    train_X,
    train_y,
    epochs = epochs,
    validation_split=0.25)
# Out:
# Epoch 1/50
# 14/14 [==============================] - 8s 55ms/step - loss: 1.1419 - accuracy: 0.5290 - val_loss: 0.6829 - val_accuracy: 0.5405
# Epoch 2/50
# 14/14 [==============================] - 0s 26ms/step - loss: 0.6787 - accuracy: 0.5475 - val_loss: 0.5913 - val_accuracy: 0.6486
# Epoch 3/50
# 14/14 [==============================] - 0s 27ms/step - loss: 0.6101 - accuracy: 0.6627 - val_loss: 0.5945 - val_accuracy: 0.6486
# Epoch 4/50
# 14/14 [==============================] - 0s 27ms/step - loss: 0.5026 - accuracy: 0.7698 - val_loss: 0.7189 - val_accuracy: 0.5811
# Epoch 5/50
# 14/14 [==============================] - 0s 27ms/step - loss: 0.4330 - accuracy: 0.8082 - val_loss: 0.4176 - val_accuracy: 0.8041
# Epoch 6/50
# 14/14 [==============================] - 0s 27ms/step - loss: 0.2833 - accuracy: 0.8722 - val_loss: 0.3633 - val_accuracy: 0.8311
# Epoch 7/50
# 14/14 [==============================] - 0s 27ms/step - loss: 0.2052 - accuracy: 0.9081 - val_loss: 0.5119 - val_accuracy: 0.7703
# Epoch 8/50
# 14/14 [==============================] - 0s 26ms/step - loss: 0.1582 - accuracy: 0.9442 - val_loss: 0.3834 - val_accuracy: 0.8446
# Epoch 9/50
# 14/14 [==============================] - 0s 34ms/step - loss: 0.1325 - accuracy: 0.9576 - val_loss: 0.3988 - val_accuracy: 0.8378
# Epoch 10/50
# 14/14 [==============================] - 0s 27ms/step - loss: 0.0833 - accuracy: 0.9715 - val_loss: 0.5194 - val_accuracy: 0.7703
# Epoch 11/50
# 14/14 [==============================] - 0s 27ms/step - loss: 0.0943 - accuracy: 0.9718 - val_loss: 0.5022 - val_accuracy: 0.8243
# Epoch 12/50
# 14/14 [==============================] - 0s 26ms/step - loss: 0.0827 - accuracy: 0.9723 - val_loss: 0.4884 - val_accuracy: 0.8243
# Epoch 13/50
# 14/14 [==============================] - 0s 27ms/step - loss: 0.0635 - accuracy: 0.9833 - val_loss: 0.5139 - val_accuracy: 0.8378
# Epoch 14/50
# 14/14 [==============================] - 0s 27ms/step - loss: 0.0575 - accuracy: 0.9774 - val_loss: 0.5613 - val_accuracy: 0.8311
# Epoch 15/50
# 14/14 [==============================] - 0s 26ms/step - loss: 0.0410 - accuracy: 0.9909 - val_loss: 0.4295 - val_accuracy: 0.8446
# Epoch 16/50
# 14/14 [==============================] - 0s 26ms/step - loss: 0.0346 - accuracy: 0.9878 - val_loss: 0.4381 - val_accuracy: 0.8716
# Epoch 17/50
# 14/14 [==============================] - 0s 26ms/step - loss: 0.0304 - accuracy: 0.9872 - val_loss: 0.6839 - val_accuracy: 0.8378
# Epoch 18/50
# 14/14 [==============================] - 0s 26ms/step - loss: 0.0643 - accuracy: 0.9830 - val_loss: 0.5906 - val_accuracy: 0.8243
# Epoch 19/50
# 14/14 [==============================] - 0s 26ms/step - loss: 0.0299 - accuracy: 0.9944 - val_loss: 0.5242 - val_accuracy: 0.8649
# Epoch 20/50
# 14/14 [==============================] - 0s 27ms/step - loss: 0.0385 - accuracy: 0.9869 - val_loss: 0.4692 - val_accuracy: 0.8581
# Epoch 21/50
# 14/14 [==============================] - 0s 27ms/step - loss: 0.0308 - accuracy: 0.9960 - val_loss: 0.5676 - val_accuracy: 0.8649
# Epoch 22/50
# 14/14 [==============================] - 0s 26ms/step - loss: 0.0518 - accuracy: 0.9763 - val_loss: 0.5098 - val_accuracy: 0.8581
# Epoch 23/50
# 14/14 [==============================] - 0s 27ms/step - loss: 0.0182 - accuracy: 0.9957 - val_loss: 0.5025 - val_accuracy: 0.8649
# Epoch 24/50
# 14/14 [==============================] - 0s 27ms/step - loss: 0.0167 - accuracy: 0.9950 - val_loss: 0.5171 - val_accuracy: 0.8649
# Epoch 25/50
# 14/14 [==============================] - 0s 26ms/step - loss: 0.0239 - accuracy: 0.9951 - val_loss: 0.6583 - val_accuracy: 0.8514
# Epoch 26/50
# 14/14 [==============================] - 0s 27ms/step - loss: 0.0219 - accuracy: 0.9889 - val_loss: 0.6282 - val_accuracy: 0.8243
# Epoch 27/50
# 14/14 [==============================] - 0s 27ms/step - loss: 0.0205 - accuracy: 0.9922 - val_loss: 0.5465 - val_accuracy: 0.8514
# Epoch 28/50
# 14/14 [==============================] - 0s 27ms/step - loss: 0.0135 - accuracy: 0.9924 - val_loss: 0.5129 - val_accuracy: 0.8716
# Epoch 29/50
# 14/14 [==============================] - 0s 27ms/step - loss: 0.0114 - accuracy: 0.9951 - val_loss: 0.5539 - val_accuracy: 0.8649
# Epoch 30/50
# 14/14 [==============================] - 0s 27ms/step - loss: 0.0092 - accuracy: 0.9985 - val_loss: 0.5299 - val_accuracy: 0.8649
# Epoch 31/50
# 14/14 [==============================] - 0s 27ms/step - loss: 0.0091 - accuracy: 0.9990 - val_loss: 0.5549 - val_accuracy: 0.8649
# Epoch 32/50
# 14/14 [==============================] - 0s 27ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.6319 - val_accuracy: 0.8446
# Epoch 33/50
# 14/14 [==============================] - 0s 26ms/step - loss: 0.0147 - accuracy: 0.9975 - val_loss: 0.6091 - val_accuracy: 0.8581
# Epoch 34/50
# 14/14 [==============================] - 0s 26ms/step - loss: 0.0303 - accuracy: 0.9915 - val_loss: 0.7050 - val_accuracy: 0.8446
# Epoch 35/50
# 14/14 [==============================] - 0s 26ms/step - loss: 0.0120 - accuracy: 0.9946 - val_loss: 0.6546 - val_accuracy: 0.8581
# Epoch 36/50
# 14/14 [==============================] - 0s 27ms/step - loss: 0.0348 - accuracy: 0.9931 - val_loss: 0.5292 - val_accuracy: 0.8784
# Epoch 37/50
# 14/14 [==============================] - 0s 26ms/step - loss: 0.0062 - accuracy: 0.9977 - val_loss: 0.5106 - val_accuracy: 0.8716
# Epoch 38/50
# 14/14 [==============================] - 0s 26ms/step - loss: 0.0045 - accuracy: 0.9990 - val_loss: 0.5527 - val_accuracy: 0.8649
# Epoch 39/50
# 14/14 [==============================] - 0s 27ms/step - loss: 0.0252 - accuracy: 0.9934 - val_loss: 0.5677 - val_accuracy: 0.8716
# Epoch 40/50
# 14/14 [==============================] - 0s 27ms/step - loss: 0.0124 - accuracy: 0.9982 - val_loss: 0.4919 - val_accuracy: 0.8919
# Epoch 41/50
# 14/14 [==============================] - 0s 26ms/step - loss: 0.0122 - accuracy: 1.0000 - val_loss: 0.4950 - val_accuracy: 0.8581
# Epoch 42/50
# 14/14 [==============================] - 0s 26ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.5423 - val_accuracy: 0.8851
# Epoch 43/50
# 14/14 [==============================] - 0s 26ms/step - loss: 0.0043 - accuracy: 0.9987 - val_loss: 0.5593 - val_accuracy: 0.8784
# Epoch 44/50
# 14/14 [==============================] - 0s 26ms/step - loss: 0.0057 - accuracy: 0.9982 - val_loss: 0.6209 - val_accuracy: 0.8919
# Epoch 45/50
# 14/14 [==============================] - 0s 27ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.5207 - val_accuracy: 0.8716
# Epoch 46/50
# 14/14 [==============================] - 0s 26ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.6122 - val_accuracy: 0.8851
# Epoch 47/50
# 14/14 [==============================] - 0s 26ms/step - loss: 0.0063 - accuracy: 0.9985 - val_loss: 0.6367 - val_accuracy: 0.8649
# Epoch 48/50
# 14/14 [==============================] - 0s 26ms/step - loss: 0.0173 - accuracy: 0.9969 - val_loss: 0.6937 - val_accuracy: 0.8581
# Epoch 49/50
# 14/14 [==============================] - 0s 27ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.5906 - val_accuracy: 0.8716
# Epoch 50/50
# 14/14 [==============================] - 0s 26ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.6809 - val_accuracy: 0.8716

# %%
from matplotlib import pyplot as plt
#Plot Training and Validation Loss
plt.plot(fitted_model.history['loss'],'r',label = 'training loss')
plt.plot(fitted_model.history['val_loss'],'b',label = 'validation loss')
plt.xlabel('Number of Epochs')
plt.ylabel('Loss Value')
plt.legend()
plt.show()

#plot training and validation Accuracy
plt.plot(fitted_model.history['accuracy'],'r',label = 'training accuracy')
plt.plot(fitted_model.history['val_accuracy'],'b',label = 'validation accuracy')
plt.xlabel('Number of Epochs')
plt.ylabel('Accuracy Value')
plt.legend()
plt.show()

# %% [markdown]
# Save or Serialize the Model

# %%
#Save or Serialize the model with the name face_mask_detection
model.save("Face_Mask_DetectionNew.h5")
